# %% [markdown]
#  Road map
# 1)IMPORTING THE LIBRARIES
#
# 2)READ THE DATASET
#
# 3) EXPLORATORY DATA ANALYSIS
#     1)understand the data                 df.info()
#     2)check the data types                df.dtypes()
#     3)check the shape of the data         df.shape()
#     4)check the statistical summary using df.info()
#     5)check for duplicates                df.duplicated.any()(removing the duplicates will check during model testing)
#     6)check for missing values            df.isnull.sum()
#     7)check for outliers                  using boxplot
#     8)converting the datatypes using encoding technique
#        ordinal encoding and label encoding are used
#      9)Feature Engineering(Scaling,Selection,Normalization)
#
# 4)DIVIDE THE DATA SET
#
# 5)TRAIN THE MODEL
#
# 6)FITTING THE MODEL

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1_hotel_bookings.ipynb',
#  'github_link.txt',
#  'hotel_bookings.csv',
#  'hotel_bookings1.ipynb',
#  'hotel_prediction.ipynb',
#  'notes.txt']

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('hotel_bookings.csv')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.lead_time.hist()

# %%
df.previous_cancellations.hist()

# %%
df.deposit_type.hist()

# %%
df.describe()

# %%
df.info()

# %% [markdown]
# EDA TASKS
# 1) converting data types arrival_date_month object into int
# 2) converting data types children float64 into int
# 3) combining 3 variables into 1 variable
# 4) dropping 3 variables arrival_date_year,arrival_date_month,arrival_date_week_number
# 5) removing duplicated values

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#print(df['company'].skew())

# %%
#df.company.hist()

# %%
#country
#print(df['agent'].skew())

# %%
#df.agent.hist()

# %%
#df.isnull().sum()*100/len(df)

# %%
# 10 kids are once,3 kids are 76 times,1 kid is 4861 times and no kids are 110796 times so mostly there are  0 kids more so we will replacw with 0
#df['children'].value_counts()

# %%
# imputing missing valeus with zero
df['children'].fillna(0,inplace=True)

# %%
#df.isnull().sum()

# %%
# to get IQR values:
#Q1 = df.quantile(0.25)
#Q3 = df.quantile(0.75)
#IQR = Q3 - Q1
#print(IQR)

# %%
# 9 is the code for agent, so 9 th agent is repeted  more  are 31961 times,240 agents are 13922 times, 1 agent is  7191 times.
#df['agent'].value_counts()

# %% [markdown]
# # Missing values imputation using mode

# %%
df['agent']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3         304.0
# 4         240.0
#           ...
# 119385    394.0
# 119386      9.0
# 119387      9.0
# 119388     89.0
# 119389      9.0
# Name: agent, Length: 119390, dtype: float64

# %%
df['agent'].fillna(9.0,inplace=True)

# %%
#df.isnull().sum()

# %%
df['country'].value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# BWA        1
# NIC        1
# VGB        1
# AIA        1
# BDI        1
# Name: country, Length: 177, dtype: int64

# %%
df['country'].fillna('PRT',inplace=True)

# %%
df['company'].value_counts()
# Out:
# 40.0     927
# 223.0    784
# 67.0     267
# 45.0     250
# 153.0    215
#         ...
# 229.0      1
# 213.0      1
# 416.0      1
# 320.0      1
# 461.0      1
# Name: company, Length: 352, dtype: int64

# %%
df['company'].fillna(40.0,inplace=True)
#done with all the missing values

# %%
#df.isnull().sum()

# %%
df['arrival_date'] = df['arrival_date_year'].astype(str)

# %%
df

# %%
import matplotlib.pyplot   as plt

# %%
#df.plot(kind='box',subplots=True,layout=(3,3),grid=True,figsize=(8,8))
#plt.tight_layout()

#plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(df['arrival_date_year'], df['stays_in_week_nights'])
ax.set_xlabel('arrival_date_year')
ax.set_ylabel('stays_in_week_nights')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(df['agent'], df['is_canceled'])
ax.set_xlabel('agent')
ax.set_ylabel('is_canceled')
plt.show()

# %%
df

# %% [markdown]
# # Detecting the outliers using IQR method

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
#attributes = ['lead_time','is_canceled','company']
#plt.rcParams['figure.figsize'] = [10,8]
#sns.boxplot(df = df[attributes], orient="v", palette="Set2" ,whis=1.5,saturation=1, width=0.7)
#plt.title("Outliers Variable Distribution", fontsize = 14, fontweight = 'bold')
#plt.ylabel("Range", fontweight = 'bold')
#plt.xlabel("Attributes", fontweight = 'bold')

# %%
# to get IQR values:
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# is_canceled                         1.00
# lead_time                         142.00
# arrival_date_year                   1.00
# arrival_date_week_number           22.00
# arrival_date_day_of_month          15.00
# stays_in_weekend_nights             2.00
# stays_in_week_nights                2.00
# adults                              0.00
# children                            0.00
# babies                              0.00
# is_repeated_guest                   0.00
# previous_cancellations              0.00
# previous_bookings_not_canceled      0.00
# booking_changes                     0.00
# agent                             220.00
# company                           208.00
# days_in_waiting_list                0.00
# adr                                56.71
# required_car_parking_spaces         0.00
# total_of_special_requests           1.00
# dtype: float64

# %%
# checking the outlier  usign the formula 
# True indicates presence of an outlier false indicates absence an outlier
print(df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))
# Out:
#           adr  adults  agent  arrival_date_day_of_month  arrival_date_month  \
# 0       False   False  False                      False               False
# 1       False   False  False                      False               False
# 2       False    True  False                      False               False
# 3       False    True  False                      False               False
# 4       False   False  False                      False               False
# ...       ...     ...    ...                        ...                 ...
# 119385  False   False  False                      False               False
# 119386  False   False  False                      False               False
# 119387  False   False  False                      False               False
# 119388  False   False  False                      False               False
# 119389  False   False  False                      False               False
#
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# # Treating the outliers using IQR method

# %%
#all the outliers are removed

df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df.shape
# Out:
# (55124, 32)

# %%
#X = df.iloc[:, 0:4].values
#y = df.iloc[:, 4].values

# %%
pf=pd.read_csv('hotel_bookings.csv')

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# 7       Resort Hotel            0          9               2015
# 8       Resort Hotel            1         85               2015
# ...              ...          ...        ...                ...
# 119381    City Hotel            0        188               2017
# 119383    City Hotel            0        164               2017
# 119384    City Hotel            0         21               2017
# 119385    City Hotel            0         23               2017
# 119388    City Hotel            0        109               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 4                    July                        27
# 5                    July                        27
# ...

# %%
y=pd.DataFrame(df['is_canceled'])

# %%
y
# Out:
#         is_canceled
# 4                 0
# 5                 0
# 6                 0
# 7                 0
# 8                 1
# ...             ...
# 119381            0
# 119383            0
# 119384            0
# 119385            0
# 119388            0
#
# [55124 rows x 1 columns]

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# 7       Resort Hotel            0          9               2015
# 8       Resort Hotel            1         85               2015
# ...              ...          ...        ...                ...
# 119381    City Hotel            0        188               2017
# 119383    City Hotel            0        164               2017
# 119384    City Hotel            0         21               2017
# 119385    City Hotel            0         23               2017
# 119388    City Hotel            0        109               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 4                    July                        27
# 5                    July                        27
# ...

# %%
 df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# 7       Resort Hotel            0          9               2015
# 8       Resort Hotel            1         85               2015
# ...              ...          ...        ...                ...
# 119381    City Hotel            0        188               2017
# 119383    City Hotel            0        164               2017
# 119384    City Hotel            0         21               2017
# 119385    City Hotel            0         23               2017
# 119388    City Hotel            0        109               2017
#
#         arrival_date_month  arrival_date_week_number  \
# 4                        5                        27
# 5                        5                        27
# ...

# %% [markdown]
# # converting object into int type for  'arrival_date_month' using label encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['arrival_date_month'] = le.fit_transform(df['arrival_date_month'])

# %% [markdown]
# # converting cat into int type for  'arrival_date_month' using one hot encoder

# %%
df_one_hot_encoder = df

# %%
#df_one_hot_encoder = pd.get_dummies(data=df_one_hot_encoder, columns=['hotel', 'meal',
                                                'country',
                                                 'market_segment',
                                                 'distribution_channel',
                                                'reserved_room_type',
                                                 'assigned_room_type',
                                                'deposit_type',
                                                'customer_type',
                                                'reservation_status',
                                                 'reservation_status_date'])
# Out:
#   File "<ipython-input-57-7a9db1c734b5>", line 2
#     'country',
#     ^
# IndentationError: unexpected indent

# %%
# Lets apply LabelEncoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df[df.select_dtypes(include = ['object']).columns] = df[df.select_dtypes(include=['object']).columns].apply(le.fit_transform)

# %%
# Now the data set is converted from Label to numeric data
df.head()
# Out:
#    hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 4      1            0         14               2015                   5
# 5      1            0         14               2015                   5
# 6      1            0          0               2015                   5
# 7      1            0          9               2015                   5
# 8      1            1         85               2015                   5
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 4                        27                          1
# 5                        27                          1
# 6                        27                          1
# 7                        27                          1
# 8                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 4                        0                     2       2  ...             0
# ...

# %%
# Now define dependent and independent variables
df_x = df.drop('is_canceled' , axis =1)
df_y = df['is_canceled']

# %%
df_x
# Out:
#         hotel  lead_time  arrival_date_year  arrival_date_month  \
# 4           1         14               2015                   5
# 5           1         14               2015                   5
# 6           1          0               2015                   5
# 7           1          9               2015                   5
# 8           1         85               2015                   5
# ...       ...        ...                ...                 ...
# 119381      0        188               2017                   1
# 119383      0        164               2017                   1
# 119384      0         21               2017                   1
# 119385      0         23               2017                   1
# 119388      0        109               2017                   1
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 4                             27                          1
# 5                             27                          1
# ...

# %%
df_y
# Out:
# 4         0
# 5         0
# 6         0
# 7         0
# 8         1
#          ..
# 119381    0
# 119383    0
# 119384    0
# 119385    0
# 119388    0
# Name: is_canceled, Length: 55124, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55124 entries, 4 to 119388
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           55124 non-null  int32
#  1   is_canceled                     55124 non-null  int64
#  2   lead_time                       55124 non-null  int64
#  3   arrival_date_year               55124 non-null  int64
#  4   arrival_date_month              55124 non-null  int32
#  5   arrival_date_week_number        55124 non-null  int64
#  6   arrival_date_day_of_month       55124 non-null  int64
#  7   stays_in_weekend_nights         55124 non-null  int64
#  8   stays_in_week_nights            55124 non-null  int64
#  9   adults                          55124 non-null  int64
#  10  children                        55124 non-null  float64
#  11  babies                          55124 non-null  int64
# ...

# %%
# Split Train and Test data set
from sklearn.model_selection import train_test_split

# %%
df_x_train, df_x_test, df_y_train, df_y_test = train_test_split(df_x,df_y, random_state=11)

# %%
# Now import some more liberaries and fit our model
from sklearn.metrics import accuracy_score , confusion_matrix
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

# %%
rf.fit(df_x_train,df_y_train)
# Out:
# RandomForestClassifier()

# %%
pred_cncl = rf.predict(df_x_test)

# %%
pred_cncl
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
accuracy_score(pred_cncl, df_y_test)
# Out:
# 0.999854872650751

# %%
confusion_matrix(pred_cncl, df_y_test)
# Out:
# array([[8360,    2],
#        [   0, 5419]], dtype=int64)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(pred_cncl, df_y_test))
#print(classification_report(y_test,y_pred))
print(accuracy_score(pred_cncl, df_y_test))
# Out:
# [[8360    2]
#  [   0 5419]]
# 0.999854872650751

# %%
print(accuracy_score(pred_cncl, df_y_test))
# Out:
# 0.999854872650751

# %%
print(classification_report(pred_cncl, df_y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8362
#            1       1.00      1.00      1.00      5419
#
#     accuracy                           1.00     13781
#    macro avg       1.00      1.00      1.00     13781
# weighted avg       1.00      1.00      1.00     13781
